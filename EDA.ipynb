# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 로드
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# 데이터 크기 확인
print("🔹 Train 데이터 크기:", train.shape)
print("🔹 Test 데이터 크기:", test.shape)

# 데이터 타입 확인
print("\n🔹 Train 데이터 정보:")
print(train.info())

# 기본 통계량 확인
print("\n🔹 Train 데이터 기초 통계:")
print(train.describe())

# 결측값 확인
print("\n🔹 Train 데이터 결측값 개수:")
print(train.isnull().sum())

print("\n🔹 Test 데이터 결측값 개수:")
print(test.isnull().sum())

# 허위매물 여부 분포 확인
plt.figure(figsize=(6,4))
sns.countplot(data=train, x='허위매물여부', palette="pastel")
plt.title("허위매물 여부 분포")
plt.show()

# 수치형 변수 분포 시각화
num_cols = ['보증금', '월세', '전용면적', '해당층', '총층', '방수', '욕실수', '총주차대수', '관리비']
train[num_cols].hist(figsize=(12, 10), bins=30, layout=(3, 3))
plt.suptitle("수치형 변수 분포")
plt.show()

# 범주형 변수 값 개수 확인
cat_cols = ['매물확인방식', '방향', '주차가능여부', '중개사무소', '제공플랫폼']
for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(data=train, x=col, palette="pastel", order=train[col].value_counts().index)
    plt.title(f"{col} 분포")
    plt.xticks(rotation=45)
    plt.show()

# 허위매물 여부에 따른 수치형 변수 비교
plt.figure(figsize=(12, 6))
for i, col in enumerate(num_cols, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(data=train, x='허위매물여부', y=col, palette="pastel")
    plt.title(f"{col} 분포")
plt.tight_layout()
plt.show()
# Out:
# 🔹 Train 데이터 크기: (2452, 17)
# 🔹 Test 데이터 크기: (613, 16)
#
# 🔹 Train 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2452 entries, 0 to 2451
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      2452 non-null   object
#  1   매물확인방식  2452 non-null   object
#  2   보증금     2452 non-null   float64
#  3   월세      2452 non-null   int64
#  4   전용면적    1665 non-null   float64
#  5   해당층     2223 non-null   float64
#  6   총층      2436 non-null   float64
#  7   방향      2452 non-null   object
#  8   방수      2436 non-null   float64
#  9   욕실수     2434 non-null   float64
#  10  주차가능여부  2452 non-null   object
#  11  총주차대수   1756 non-null   float64
#  12  관리비     2452 non-null   int64
#  13  중개사무소   2452 non-null   object
#  14  제공플랫폼   2452 non-null   object
#  15  게재일     2452 non-null   object
#  16  허위매물여부  2452 non-null   int64
# dtypes: float64(7), int64(3), object(7)
# memory usage: 325.8+ KB
# None
#
# ...
